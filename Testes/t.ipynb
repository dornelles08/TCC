# %%
import pandas as pd

# %%
fipe = pd.read_csv("./tabelaFipe.csv")
fipe.head()
# Out:
#    marca.codigo marca.nome  modelo.codigo     modelo.nome ano.codigo  \
# 0             1      Acura              1  Integra GS 1.8     1991-1
# 1             1      Acura              1  Integra GS 1.8     1992-1
# 2             1      Acura              2  Legend 3.2/3.5     1991-1
# 3             1      Acura              2  Legend 3.2/3.5     1992-1
# 4             1      Acura              2  Legend 3.2/3.5     1993-1
#
#         ano.nome info.Marca     info.Modelo  info.CodigoFipe  info.AnoModelo  \
# 0  1991 Gasolina      Acura  Integra GS 1.8                0            1991
# 1  1992 Gasolina      Acura  Integra GS 1.8                0            1992
# 2  1991 Gasolina      Acura  Legend 3.2/3.5                0            1991
# 3  1992 Gasolina      Acura  Legend 3.2/3.5                0            1992
# 4  1993 Gasolina      Acura  Legend 3.2/3.5                0            1993
#
#    info.TipoVeiculo  info.Valor   Ano Trimestre      Mês  Dia  \
# ...

# %%
fipe[["modelo.nome"]].drop_duplicates().where("Ka" in "modelo.nome")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /home/dornelles/TCC/Testes/t.ipynb Cell 3 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/home/dornelles/TCC/Testes/t.ipynb#ch0000010?line=0'>1</a> fipe[["modelo.nome"]].drop_duplicates().where("Ka" in "modelo.nome")
#
# File ~/TCC/Testes/venv/lib/python3.10/site-packages/pandas/util/_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~/TCC/Testes/venv/lib/python3.10/site-packages/pandas/core/frame.py:10955, in DataFrame.where(self, cond, other, inplace, axis, level, errors, try_cast)
# ...

# %%
ka = pd.read_csv("./dados/sp_ka.csv")
ka.head()
# Out:
#    modelo  marca  combustivel  cambio  direcao  cor   ano  quilometragem  \
# 0    4159      8            4       2        1    0  2017          76000
# 1    4159      8            4       2        1    9  2018          99999
# 2    4159      8            4       2        1    0  2015          36000
# 3    4159      8            4       2        2    0  2017          64000
# 4    4159      8            4       2        2    0  2017          87000
#
#    potenciamotor  blindado    valor
# 0            1.0         0  39990.0
# 1            1.0         0  39990.0
# 2            1.0         0  37490.0
# 3            1.0         0  37500.0
# 4            1.0         0  33000.0
